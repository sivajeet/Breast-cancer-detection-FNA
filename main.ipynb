# %%
import pickle


with open('./Breast-cancer-FNA/wdbc.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data
# mean_texture,worst_area,worst_smoothness
# Out:
#            id  malignant  radius_0  texture_0  perimeter_0  area_0  \
# 0      842302          1     17.99      10.38       122.80  1001.0
# 1      842517          1     20.57      17.77       132.90  1326.0
# 2    84300903          1     19.69      21.25       130.00  1203.0
# 3    84348301          1     11.42      20.38        77.58   386.1
# 4    84358402          1     20.29      14.34       135.10  1297.0
# ..        ...        ...       ...        ...          ...     ...
# 564    926424          1     21.56      22.39       142.00  1479.0
# 565    926682          1     20.13      28.25       131.20  1261.0
# 566    926954          1     16.60      28.08       108.30   858.1
# 567    927241          1     20.60      29.33       140.10  1265.0
# 568     92751          0      7.76      24.54        47.92   181.0
#
#      smoothness_0  compactness_0  concavity_0  concave points_0  ...  \
# 0         0.11840        0.27760      0.30010           0.14710  ...
# ...

# %%
data.describe()
# Out:
#                  id   malignant    radius_0   texture_0  perimeter_0  \
# count  5.690000e+02  569.000000  569.000000  569.000000   569.000000
# mean   3.037183e+07    0.372583   14.127292   19.289649    91.969033
# std    1.250206e+08    0.483918    3.524049    4.301036    24.298981
# min    8.670000e+03    0.000000    6.981000    9.710000    43.790000
# 25%    8.692180e+05    0.000000   11.700000   16.170000    75.170000
# 50%    9.060240e+05    0.000000   13.370000   18.840000    86.240000
# 75%    8.813129e+06    1.000000   15.780000   21.800000   104.100000
# max    9.113205e+08    1.000000   28.110000   39.280000   188.500000
#
#             area_0  smoothness_0  compactness_0  concavity_0  \
# count   569.000000    569.000000     569.000000   569.000000
# mean    654.889104      0.096360       0.104341     0.088799
# std     351.914129      0.014064       0.052813     0.079720
# min     143.500000      0.052630       0.019380     0.000000
# ...

# %% [markdown]
# ### Finding any possible missing or null data points - using pandas function

# %%
data.isnull().sum()
data.isna().sum()
# Out:
# id                     0
# malignant              0
# radius_0               0
# texture_0              0
# perimeter_0            0
# area_0                 0
# smoothness_0           0
# compactness_0          0
# concavity_0            0
# concave points_0       0
# symmetry_0             0
# fractal dimension_0    0
# radius_1               0
# texture_1              0
# perimeter_1            0
# area_1                 0
# smoothness_1           0
# compactness_1          0
# concavity_1            0
# concave points_1       0
# symmetry_1             0
# fractal dimension_1    0
# radius_2               0
# texture_2              0
# perimeter_2            0
# area_2                 0
# smoothness_2           0
# compactness_2          0
# concavity_2            0
# concave points_2       0
# symmetry_2             0
# fractal dimension_2    0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# _0", "_1", "_2" represent the mean, standard deviation and "worst"

# %%
import numpy as np

# %%
data.var().sort_values(ascending=False)
# Out:
# id                     1.563015e+16
# area_2                 3.241674e+05
# area_0                 1.238436e+05
# area_1                 2.069432e+03
# perimeter_2            1.129131e+03
# perimeter_0            5.904405e+02
# texture_2              3.777648e+01
# radius_2               2.336022e+01
# texture_0              1.849891e+01
# radius_0               1.241892e+01
# perimeter_1            4.087896e+00
# texture_1              3.043159e-01
# malignant              2.341766e-01
# radius_1               7.690235e-02
# concavity_2            4.352409e-02
# compactness_2          2.475477e-02
# concavity_0            6.355248e-03
# concave points_2       4.320741e-03
# symmetry_2             3.827584e-03
# compactness_0          2.789187e-03
# concave points_0       1.505661e-03
# concavity_1            9.111982e-04
# symmetry_0             7.515428e-04
# smoothness_2           5.213198e-04
# fractal dimension_2    3.262094e-04
# compactness_1          3.207029e-04
# ...

# %%
data.corr()
# Out:
#                            id  malignant  radius_0  texture_0  perimeter_0  \
# id                   1.000000   0.039769  0.074626   0.099770     0.073159
# malignant            0.039769   1.000000  0.730029   0.415185     0.742636
# radius_0             0.074626   0.730029  1.000000   0.323782     0.997855
# texture_0            0.099770   0.415185  0.323782   1.000000     0.329533
# perimeter_0          0.073159   0.742636  0.997855   0.329533     1.000000
# area_0               0.096893   0.708984  0.987357   0.321086     0.986507
# smoothness_0        -0.012968   0.358560  0.170581  -0.023389     0.207278
# compactness_0        0.000096   0.596534  0.506124   0.236702     0.556936
# concavity_0          0.050080   0.696360  0.676764   0.302418     0.716136
# concave points_0     0.044158   0.776614  0.822529   0.293464     0.850977
# symmetry_0          -0.022114   0.330499  0.147741   0.071401     0.183027
# ...

# %%
def plotSizeDistribution(d):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(d, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'concavity_0', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('concavity_0', 'Count')
    distributionOne.fig.suptitle('concavity vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(d, hue="malignant",aspect=2.5)
    distributionTwo.map(sns.kdeplot,'concavity_0',shade=True)
    distributionTwo.set(xlim=(0, d['concavity_0'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('concavity_0', 'Proportion')
    distributionTwo.fig.suptitle('concavity vs malignant (Blue = Malignant; Orange = Benign)')

plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'concavity_1', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('concavity_1', 'Count')
    distributionOne.fig.suptitle('concavity vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionTwo.map(sns.kdeplot,'concavity_1',shade=True)
    distributionTwo.set(xlim=(0, a['concavity_1'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('concavity_1', 'Proportion')
    distributionTwo.fig.suptitle('concavity vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'area_0', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('area_0', 'Count')
    distributionOne.fig.suptitle('Area vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionTwo.map(sns.kdeplot,'area_0',shade=True)
    distributionTwo.set(xlim=(0, a['area_0'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('area_0', 'Proportion')
    distributionTwo.fig.suptitle('Area vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'area_1', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('area_1', 'Count')
    distributionOne.fig.suptitle('Area vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionTwo.map(sns.kdeplot,'area_1',shade=True)
    distributionTwo.set(xlim=(0, a['area_1'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('area_1', 'Proportion')
    distributionTwo.fig.suptitle('Area vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'area_2', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('area_2', 'Count')
    distributionOne.fig.suptitle('Area vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionTwo.map(sns.kdeplot,'area_2',shade=True)
    distributionTwo.set(xlim=(0, a['area_2'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('area_2', 'Proportion')
    distributionTwo.fig.suptitle('Area2 vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'texture_0', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('texture_0', 'Count')
    distributionOne.fig.suptitle('texture vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionTwo.map(sns.kdeplot,'texture_0',shade=True)
    distributionTwo.set(xlim=(0, a['texture_0'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('texture_0', 'Proportion')
    distributionTwo.fig.suptitle('texture vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'texture_1', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('texture_1', 'Count')
    distributionOne.fig.suptitle('texture vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionTwo.map(sns.kdeplot,'texture_1',shade=True)
    distributionTwo.set(xlim=(0, a['texture_1'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('texture_1', 'Proportion')
    distributionTwo.fig.suptitle('texture vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'texture_2', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('texture_2', 'Count')
    distributionOne.fig.suptitle('texture vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionTwo.map(sns.kdeplot,'texture_2',shade=True)
    distributionTwo.set(xlim=(0, a['texture_2'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('texture_2', 'Proportion')
    distributionTwo.fig.suptitle('texture vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'symmetry_0', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('symmetry_0', 'Count')
    distributionOne.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionTwo.map(sns.kdeplot,'symmetry_0',shade=True)
    distributionTwo.set(xlim=(0, a['symmetry_0'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('symmetry_0', 'Proportion')
    distributionTwo.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'symmetry_1', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('symmetry_1', 'Count')
    distributionOne.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionTwo.map(sns.kdeplot,'symmetry_1',shade=True)
    distributionTwo.set(xlim=(0, a['symmetry_1'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('symmetry_1', 'Proportion')
    distributionTwo.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'symmetry_2', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('symmetry_2', 'Count')
    distributionOne.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionTwo.map(sns.kdeplot,'symmetry_2',shade=True)
    distributionTwo.set(xlim=(0, a['symmetry_2'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('symmetry_2', 'Proportion')
    distributionTwo.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'smoothness_0', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('smoothness_0', 'Count')
    distributionOne.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    
    distributionTwo.map(sns.kdeplot,'smoothness_0',shade=True)
    distributionTwo.set(xlim=(0, a['smoothness_0'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('smoothness_0', 'Proportion')
    distributionTwo.fig.suptitle('smoothness vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'radius_0', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('radius_0', 'Count')
    distributionOne.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    
    distributionTwo.map(sns.kdeplot,'radius_0',shade=True)
    distributionTwo.set(xlim=(0, a['radius_0'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('radius_0', 'Proportion')
    distributionTwo.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'radius_1', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('radius_1', 'Count')
    distributionOne.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    
    distributionTwo.map(sns.kdeplot,'radius_1',shade=True)
    distributionTwo.set(xlim=(0, a['radius_1'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('radius_1', 'Proportion')
    distributionTwo.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'radius_2', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('radius_2', 'Count')
    distributionOne.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    
    distributionTwo.map(sns.kdeplot,'radius_2',shade=True)
    distributionTwo.set(xlim=(0, a['radius_2'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('radius_2', 'Proportion')
    distributionTwo.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'compactness_0', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('compactness_0', 'Count')
    distributionOne.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    
    distributionTwo.map(sns.kdeplot,'compactness_0',shade=True)
    distributionTwo.set(xlim=(0, a['compactness_0'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('compactness_0', 'Proportion')
    distributionTwo.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'compactness_1', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('compactness_1', 'Count')
    distributionOne.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    
    distributionTwo.map(sns.kdeplot,'compactness_1',shade=True)
    distributionTwo.set(xlim=(0, a['compactness_1'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('compactness_1', 'Proportion')
    distributionTwo.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'compactness_2', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('compactness_2', 'Count')
    distributionOne.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    
    distributionTwo.map(sns.kdeplot,'compactness_2',shade=True)
    distributionTwo.set(xlim=(0, a['compactness_2'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('compactness_2', 'Proportion')
    distributionTwo.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %%
def plotSizeDistribution(a):
    """ 
    Plot size distribution for benign vs malignant samples
    """  
    sns.set_style("whitegrid")
    distributionOne = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    distributionOne.map(plt.hist, 'perimeter_0', bins=30)
    distributionOne.add_legend()
    distributionOne.set_axis_labels('perimeter_0', 'Count')
    distributionOne.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
    distributionTwo = sns.FacetGrid(a, hue="malignant",aspect=2.5)
    
    distributionTwo.map(sns.kdeplot,'perimeter_0',shade=True)
    distributionTwo.set(xlim=(0, a['perimeter_0'].max()))
    distributionTwo.add_legend()
    distributionTwo.set_axis_labels('perimeter_0', 'Proportion')
    distributionTwo.fig.suptitle('symmetry vs malignant (Blue = Malignant; Orange = Benign)')
plotSizeDistribution(data)

# %% [markdown]
# data.area 700
# concavity 0.8
# texture 19

# %%
rule_base_data = data.copy()

# %%
rule_base_data["predict_malignant"] =1

# %% [markdown]
# (rule_base_data['symmetry_2']<=0.3)
# (rule_base_data['texture_0']<=17)
# (rule_base_data['concavity_0']<= 0.08)
# (rule_base_data['area_0']<=630)
# (rule_base_data['area_2']<=630)

# %%
rule_base_data.loc[((rule_base_data['area_2']<=690) | (rule_base_data['concavity_0']<= 0.08)
 | (rule_base_data['texture_0']<=17) | (rule_base_data['smoothness_0']<=0.084)),'predict_malignant']=0

# %%
rule_base_data.loc[rule_base_data['predict_malignant'] == 1]
# Out:
#            id  malignant  radius_0  texture_0  perimeter_0  area_0  \
# 0      842302          1     17.99      10.38       122.80  1001.0
# 1      842517          1     20.57      17.77       132.90  1326.0
# 3    84348301          1     11.42      20.38        77.58   386.1
# 4    84358402          1     20.29      14.34       135.10  1297.0
# 5      843786          1     12.45      15.70        82.57   477.1
# ..        ...        ...       ...        ...          ...     ...
# 558    925277          0     14.59      22.68        96.39   657.1
# 559    925291          0     11.51      23.93        74.52   403.5
# 560    925292          0     14.05      27.15        91.38   600.4
# 561    925311          0     11.20      29.37        70.67   386.0
# 568     92751          0      7.76      24.54        47.92   181.0
#
#      smoothness_0  compactness_0  concavity_0  concave points_0  ...  \
# 0         0.11840        0.27760      0.30010           0.14710  ...
# ...

# %%
rule_base_data.loc[((rule_base_data['predict_malignant']==0))]
# Out:
#            id  malignant  radius_0  texture_0  perimeter_0  area_0  \
# 2    84300903          1     19.69      21.25        130.0  1203.0
# 6      844359          1     18.25      19.98        119.6  1040.0
# 12     846226          1     19.17      24.80        132.4  1123.0
# 13     846381          1     15.85      23.95        103.7   782.7
# 17   84862001          1     16.13      20.68        108.1   798.8
# ..        ...        ...       ...        ...          ...     ...
# 563    926125          1     20.92      25.09        143.0  1347.0
# 564    926424          1     21.56      22.39        142.0  1479.0
# 565    926682          1     20.13      28.25        131.2  1261.0
# 566    926954          1     16.60      28.08        108.3   858.1
# 567    927241          1     20.60      29.33        140.1  1265.0
#
#      smoothness_0  compactness_0  concavity_0  concave points_0  ...  \
# 2         0.10960         0.1599      0.19740           0.12790  ...
# ...

# %%
from sklearn.metrics import accuracy_score,recall_score

# %%
accuracy_score(rule_base_data["malignant"], rule_base_data["predict_malignant"])*100
# Out:
# 91.3884007029877

# %%
import pandas as pd
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
rule_base_data.loc[(rule_base_data["malignant"] != rule_base_data["predict_malignant"])]
# Out:
#            id  malignant  radius_0  texture_0  perimeter_0  area_0  \
# 0      842302          1     17.99      10.38       122.80  1001.0
# 3    84348301          1     11.42      20.38        77.58   386.1
# 4    84358402          1     20.29      14.34       135.10  1297.0
# 5      843786          1     12.45      15.70        82.57   477.1
# 10     845636          1     16.02      23.24       102.70   797.8
# 14   84667401          1     13.73      22.61        93.60   578.3
# 16     848406          1     14.68      20.13        94.74   684.5
# 22    8511133          1     15.34      14.26       102.50   704.4
# 25     852631          1     17.14      16.40       116.00   912.7
# 29     853201          1     17.57      15.05       115.00   955.1
# 38     855133          1     14.99      25.20        95.54   698.8
# 40     855167          1     13.44      21.58        86.18   563.0
# 41     855563          1     10.95      21.35        71.90   371.1
# ...

# %%
data
# Out:
#            id  malignant  radius_0  texture_0  perimeter_0  area_0  \
# 0      842302          1     17.99      10.38       122.80  1001.0
# 1      842517          1     20.57      17.77       132.90  1326.0
# 2    84300903          1     19.69      21.25       130.00  1203.0
# 3    84348301          1     11.42      20.38        77.58   386.1
# 4    84358402          1     20.29      14.34       135.10  1297.0
# ..        ...        ...       ...        ...          ...     ...
# 564    926424          1     21.56      22.39       142.00  1479.0
# 565    926682          1     20.13      28.25       131.20  1261.0
# 566    926954          1     16.60      28.08       108.30   858.1
# 567    927241          1     20.60      29.33       140.10  1265.0
# 568     92751          0      7.76      24.54        47.92   181.0
#
#      smoothness_0  compactness_0  concavity_0  concave points_0  ...  \
# 0         0.11840        0.27760      0.30010           0.14710  ...
# ...

# %%
Y = data.iloc[:,1].values
x = data[['texture_0','area_2','smoothness_2']]
x
# Out:
#      texture_0  area_2  smoothness_2
# 0        10.38  2019.0       0.16220
# 1        17.77  1956.0       0.12380
# 2        21.25  1709.0       0.14440
# 3        20.38   567.7       0.20980
# 4        14.34  1575.0       0.13740
# ..         ...     ...           ...
# 564      22.39  2027.0       0.14100
# 565      28.25  1731.0       0.11660
# 566      28.08  1124.0       0.11390
# 567      29.33  1821.0       0.16500
# 568      24.54   268.6       0.08996
#
# [569 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, Y, test_size = 0.3, random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier()
forest.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
print('Random Forest Training Accuracy : ',forest.score(X_train, Y_train))
# Out:
# Random Forest Training Accuracy :  1.0

# %%
print('Random Forest Training Accuracy : ',forest.score(X_test, Y_test)*100)
# Out:
# Random Forest Training Accuracy :  96.49122807017544

# %%
x_full = data.iloc[:,2:]
x_full
# Out:
#      radius_0  texture_0  perimeter_0  area_0  smoothness_0  compactness_0  \
# 0       17.99      10.38       122.80  1001.0       0.11840        0.27760
# 1       20.57      17.77       132.90  1326.0       0.08474        0.07864
# 2       19.69      21.25       130.00  1203.0       0.10960        0.15990
# 3       11.42      20.38        77.58   386.1       0.14250        0.28390
# 4       20.29      14.34       135.10  1297.0       0.10030        0.13280
# ..        ...        ...          ...     ...           ...            ...
# 564     21.56      22.39       142.00  1479.0       0.11100        0.11590
# 565     20.13      28.25       131.20  1261.0       0.09780        0.10340
# 566     16.60      28.08       108.30   858.1       0.08455        0.10230
# 567     20.60      29.33       140.10  1265.0       0.11780        0.27700
# 568      7.76      24.54        47.92   181.0       0.05263        0.04362
#
# ...

# %%
Y = data.iloc[:,1].values
x_full = data.iloc[:,2:]

from sklearn.model_selection import train_test_split
X_train_full, X_test_full, Y_train_full, Y_test_full = train_test_split(x_full, Y, test_size = 0.3, random_state = 0)
from sklearn.ensemble import RandomForestClassifier
forest_full = RandomForestClassifier()
forest_full.fit(X_train_full, Y_train_full)
print('Random Forest Training Accuracy : ',forest_full.score(X_test_full, Y_test_full)*100)
# Out:
# Random Forest Training Accuracy :  95.32163742690058

# %%
y_pred_test =forest_full.predict(X_test_full)

# %%
from sklearn.metrics import recall_score
recall_score(Y_test_full, y_pred_test, average='macro')
# Out:
# 0.9497354497354498

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test_full, y_pred_test,))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       108
#            1       0.94      0.94      0.94        63
#
#     accuracy                           0.95       171
#    macro avg       0.95      0.95      0.95       171
# weighted avg       0.95      0.95      0.95       171

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_Scaler = sc.fit_transform(X_train_full)
X_test_Scaler = sc.fit_transform(X_test_full)

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(X_train_Scaler, Y_train_full)
print('LogisticRegression Training Accuracy : ',log.score(X_test_Scaler, Y_test_full)*100)
# Out:
# LogisticRegression Training Accuracy :  96.49122807017544

# %%
y_pred_test_log =forest_full.predict(X_test_Scaler)
print(classification_report(Y_test_full, y_pred_test_log))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      1.00      0.79       108
#            1       1.00      0.06      0.12        63
#
#     accuracy                           0.65       171
#    macro avg       0.82      0.53      0.45       171
# weighted avg       0.78      0.65      0.54       171
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, Y, test_size = 0.3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
def models(X_train, Y_train):
    
    #Logistic Regression
    from sklearn.linear_model import LogisticRegression
    log = LogisticRegression()
    log.fit(X_train, Y_train)
    

    #Random Forest
    from sklearn.ensemble import RandomForestClassifier
    forest = RandomForestClassifier()
    forest.fit(X_train, Y_train)
    
    #Print the model accuracy of training data
    print('[0]Logistic Regression Training Accuracy : ',log.score(X_train, Y_train))
    print('[2]Random Forest Training Accuracy : ',forest.score(X_train, Y_train))
    
    return log, forest

# %%
model = models(X_train, Y_train)
# Out:
# [0]Logistic Regression Training Accuracy :  0.964824120603015
# [2]Random Forest Training Accuracy :  1.0

# %%
from sklearn.metrics import classification_report, accuracy_score
for i in range (len(model)):
    print('Model :',model[i])
    print(classification_report(Y_test,model[i].predict(X_test)))
    print(accuracy_score(Y_test,model[i].predict(X_test)))
    print()
# Out:
# Model : LogisticRegression()
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       108
#            1       0.98      0.97      0.98        63
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171
#
# 0.9824561403508771
#
# Model : RandomForestClassifier()
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98       108
#            1       0.93      1.00      0.96        63
#
#     accuracy                           0.97       171
#    macro avg       0.96      0.98      0.97       171
# weighted avg       0.97      0.97      0.97       171
#
# 0.9707602339181286
